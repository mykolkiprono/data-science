# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dtypes = {"front_garden":'category',"large_living_room":'category',"swimming_pool":'category',"parking_space":'category',"wall_fence":'category',"water_front":'category'}

# %%
df = pd.read_csv("C:/Users/VEDIT/Desktop/machine learning/datasets/linear_regression/house_prices_datasets/house_price_dataset_original_v2_with_categorical_features.csv", dtype = dtypes)

# %%
df.head()
# Out:
#   land_size_sqm house_size_sqm  no_of_rooms  no_of_bathrooms  \
# 0       201 sqm        177 sqm            3                1
# 1       196 sqm        182 sqm            4                3
# 2       198 sqm        182 sqm            4                4
# 3       178 sqm        166 sqm            2                3
# 4       183 sqm        165 sqm            3                1
#
#   large_living_room parking_space front_garden swimming_pool  \
# 0                No           Yes          Yes            No
# 1               Yes           Yes           No           Yes
# 2               Yes           Yes           No           Yes
# 3                No           Yes           No            No
# 4               Yes           Yes           No            No
#
#   distance_to_school wall_fence house_age water_front distance_to_supermarket  \
# 0              3.3km        Yes  10 Years          No                  6.8 km
# ...

# %%
sns.set(style = 'darkgrid')

# %%
df.head()
# Out:
#   land_size_sqm house_size_sqm  no_of_rooms  no_of_bathrooms  \
# 0       201 sqm        177 sqm            3                1
# 1       196 sqm        182 sqm            4                3
# 2       198 sqm        182 sqm            4                4
# 3       178 sqm        166 sqm            2                3
# 4       183 sqm        165 sqm            3                1
#
#   large_living_room parking_space front_garden swimming_pool  \
# 0                No           Yes          Yes            No
# 1               Yes           Yes           No           Yes
# 2               Yes           Yes           No           Yes
# 3                No           Yes           No            No
# 4               Yes           Yes           No            No
#
#   distance_to_school wall_fence house_age water_front distance_to_supermarket  \
# 0              3.3km        Yes  10 Years          No                  6.8 km
# ...

# %%
df.select_dtypes(include = 'category')
# Out:
#      large_living_room parking_space front_garden swimming_pool wall_fence  \
# 0                   No           Yes          Yes            No        Yes
# 1                  Yes           Yes           No           Yes        Yes
# 2                  Yes           Yes           No           Yes         No
# 3                   No           Yes           No            No         No
# 4                  Yes           Yes           No            No        Yes
# ...                ...           ...          ...           ...        ...
# 4949               Yes           Yes          Yes           Yes        Yes
# 4950               Yes           Yes          Yes           Yes        Yes
# 4951               Yes           Yes           No            No        Yes
# 4952                No           Yes           No           Yes         No
# 4953               Yes           Yes          Yes           Yes        Yes
#
#      water_front
# 0             No
# 1             No
# ...

# %%
def func(x):
    x = ''.join(re.split("[^0-9.]*", str(x)))
    return np.float(x)

# %%
import re

# %%
df[['house_age','distance_to_school','distance_to_supermarket','land_size_sqm','house_size_sqm']] = df[['house_age','distance_to_school','distance_to_supermarket','land_size_sqm','house_size_sqm']].applymap(func)

# %%
df.head()
# Out:
#    land_size_sqm  house_size_sqm  no_of_rooms  no_of_bathrooms  \
# 0          201.0           177.0            3                1
# 1          196.0           182.0            4                3
# 2          198.0           182.0            4                4
# 3          178.0           166.0            2                3
# 4          183.0           165.0            3                1
#
#   large_living_room parking_space front_garden swimming_pool  \
# 0                No           Yes          Yes            No
# 1               Yes           Yes           No           Yes
# 2               Yes           Yes           No           Yes
# 3                No           Yes           No            No
# 4               Yes           Yes           No            No
#
#    distance_to_school wall_fence  house_age water_front  \
# 0                 3.3        Yes       10.0          No
# 1                 1.2        Yes       11.0          No
# ...

# %%
# fig = plt.figure()
# ax = fig.subplots(111)
sns.relplot(x=df['property_value'], y=df['land_size_sqm'], hue = df['front_garden'], style = df['swimming_pool'])
# plt.show()

# %%
dir(sns.FacetGrid)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bottom_axes',
#  '_clean_axis',
#  '_facet_color',
#  '_facet_plot',
#  '_finalize_grid',
#  '_get_palette',
#  '_inner_axes',
#  '_left_axes',
#  '_legend_out',
#  '_margin_titles',
#  '_not_bottom_axes',
#  '_not_left_axes',
#  '_update_legend_data',
#  'add_legend',
#  'ax',
#  'axes',
#  'axes_dict',
#  'despine',
#  'facet_axis',
#  'facet_data',
#  'fig',
#  'legend',
#  'map',
#  'map_dataframe',
#  'savefig',
#  'set',
#  'set_axis_labels',
#  'set_titles',
#  'set_xlabels',
#  'set_xticklabels',
#  'set_ylabels',
#  'set_yticklabels',
#  'tight_layout']

# %%
print(sns.FacetGrid)
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %%
df['front_garden'].value_counts()
# Out:
# Yes    3109
# No     1845
# Name: front_garden, dtype: int64

# %%
sns.relplot(x=df['property_value'], y=df['land_size_sqm'], hue = df['distance_to_supermarket'], palette='ch:r = -0.5 , l = 0.75')
# categoriclal pallete 
# qualitative pallete

# %%
df.head()
# Out:
#    land_size_sqm  house_size_sqm  no_of_rooms  no_of_bathrooms  \
# 0          201.0           177.0            3                1
# 1          196.0           182.0            4                3
# 2          198.0           182.0            4                4
# 3          178.0           166.0            2                3
# 4          183.0           165.0            3                1
#
#   large_living_room parking_space front_garden swimming_pool  \
# 0                No           Yes          Yes            No
# 1               Yes           Yes           No           Yes
# 2               Yes           Yes           No           Yes
# 3                No           Yes           No            No
# 4               Yes           Yes           No            No
#
#    distance_to_school wall_fence  house_age water_front  \
# 0                 3.3        Yes       10.0          No
# 1                 1.2        Yes       11.0          No
# ...

# %%
sns.relplot(x=df['property_value'], y=df['land_size_sqm'], size = df['distance_to_school'], sizes = (15,200))

# %%
sns.relplot(x=df['property_value'], y=df['land_size_sqm'], style = df['wall_fence'])

# %%
from numpy.random  import randn

# %%
df1 = pd.DataFrame(dict(time = np.arange(500),value = randn(500).cumsum()))

# %%
df1.head()
# Out:
#    time     value
# 0     0 -0.870630
# 1     1 -0.670573
# 2     2 -2.444471
# 3     3 -4.085497
# 4     4 -4.086242

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df1)

# %%
df2 = pd.DataFrame(randn(500,2).cumsum(axis = 0), columns = ['time', 'value'])

# %%
df2
# Out:
#           time      value
# 0    -1.073716   2.472854
# 1     0.812127   3.338692
# 2     1.225731   5.069268
# 3     1.708395   3.385035
# 4     1.200405   5.365257
# ..         ...        ...
# 495  12.169993  16.110536
# 496  11.570637  17.362705
# 497  11.372726  16.748380
# 498  11.272895  15.950481
# 499  11.005499  17.441112
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'time', y = 'value', data = df2, kind = 'line', sort = False)

# %%
# fmri = sns.load_dataset('fmri')

# %%
df3 = pd.DataFrame(dict(one = np.arange(500),two = np.arange(500)+randn(500)))

# %%
df3
# Out:
#      one         two
# 0      0   -0.115208
# 1      1    0.643927
# 2      2    1.872164
# 3      3    2.203011
# 4      4    2.489577
# ..   ...         ...
# 495  495  494.528343
# 496  496  495.100594
# 497  497  497.815652
# 498  498  497.393004
# 499  499  498.062906
#
# [500 rows x 2 columns]

# %%
sns.relplot(x = 'two', y = 'one', data = df3, kind = 'line', ci = True)

# %%
sns.relplot(x = 'land_size_sqm', y = 'no_of_bathrooms', kind = 'line', sort = True, data = df, ci = False)

# %%
sns.relplot(x = 'land_size_sqm', y = 'no_of_bathrooms', kind = 'line', sort = True, data = df, estimator = None)

# %%
sns.relplot(x = 'property_value', y = 'house_size_sqm',hue = 'parking_space', kind = 'line',sort = True, data = df)

# %%
sns.relplot(x = 'property_value', y = 'house_size_sqm',hue = 'parking_space',style = 'front_garden', kind = 'line',sort = True, data = df)

# %%
sns.relplot(x = 'property_value', y = 'house_size_sqm',hue = 'parking_space',style = 'front_garden', kind = 'line',sort = True, data = df,markers = True, dashes = False)

# %%
import nltk
