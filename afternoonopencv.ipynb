# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image  = cv.imread("C:/Users/VEDIT/Desktop/mike/judson-moore-UrgYjACxvaI-unsplash.jpg")
cv.imshow('image',image)
cv.waitKey(0)
# Out:
# -1

# %%
gray = cv.cvtColor(image,cv.COLOR_BGR2GRAY)
cv.imshow('gray',gray)
cv.waitKey(0)
# Out:
# -1

# %%
thresholds = [cv.THRESH_BINARY,cv.THRESH_BINARY_INV,cv.THRESH_TRUNC,cv.THRESH_TOZERO,cv.THRESH_TOZERO_INV]

# %%
    cv.imshow('thresh',thresh)
    cv.waitKey(0)
# Out:
# i
# i
# i
# i
# i

# %%
fig,ax = plt.subplots(1,5,figsize = (12,12))
for ax,i in zip(ax,thresholds):
#     print('i')
    ret,thresh = cv.threshold(gray,125,255,i)
    ax.imshow(thresh)
#     ax.set_title("thresh %"%i)
    ax.set_axis_off()

# %%
erode =  cv.erode(thresh,(3,3),iterations = 3)
cv.imshow('eroded',erode)
cv.waitKey(0)
# Out:
# -1

# %%
dilated = cv.dilate(erode,(3,3),iterations = 3)
cv.imshow('dilate',dilated)
cv.waitKey(0)
# Out:
# -1

# %%
thresh = cv.adaptiveThreshold(gray,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,11,2)
# th2 = cv.adaptiveThreshold(gray,255,cv.ADAPTIVE_THRESH_MEAN_C,cv.THRESH_BINARY,11,2)
cv.imshow('thresh',thresh)
cv.waitKey(0)
# Out:
# -1

# %%
th3 = cv.adaptiveThreshold(gray,255,cv.ADAPTIVE_THRESH_GAUSSIAN_C,cv.THRESH_BINARY,11,2)
cv.imshow('adt',th3)
cv.waitKey(0)
# Out:
# -1

# %%
ret,thresh = cv.threshold(gray,0,255,cv.THRESH_BINARY + cv.THRESH_OTSU)
cv.imshow('thresh',thresh)
cv.waitKey(0)
# Out:
# -1

# %%
heigth,width = image.shape[:2]

# %%
res = cv.resize(image,(heigth*2,width*2),cv.INTER_LINEAR)
cv.imshow('res',res)
cv.waitKey(0)
# Out:
# -1

# %%
res = cv.resize(image,None,fx = 0.5,fy = 0.5,interpolation = cv.INTER_AREA)
cv.imshow('res',res)
cv.waitKey(0)
# Out:
# -1

# %%
def translate(image,x,y):
    transmat = np.float32([[1,0,x],[0,1,y]])
    dimensions = (image.shape[1],image.shape[0])
    return cv.warpAffine(image,transmat,dimensions)

# %%
trans = translate(image,-100,-100)
cv.imshow('trans',trans)
cv.waitKey(0)
# Out:
# -1

# %%
def rotate(image,angle,rotpoint = None):
    height,width = image.shape[:2]
    if(rotpoint==None):
        rotpoint = (width//2,height//2)
    dimensions = (width,heigth)
    rotmat = cv.getRotationMatrix2D(rotpoint,angle,1.0)
    return cv.warpAffine(image,rotmat,dimensions)

# %%
rotated = rotate(image,-90)
cv.imshow('rotated',rotated)
cv.waitKey(0)
# Out:
# -1

# %%
pts1 = np.float32([[50,50],[200,50],[50,200]])
pts2 = np.float32([[10,100],[200,50],[100,250]])
rows,cols,ch = image.shape

# %%
M = cv.getAffineTransform(pts1,pts2)
dst = cv.warpAffine(image,M,(cols,rows))

# %%
cv.imshow('dst',dst)
cv.waitKey(0)
# Out:
# -1

# %%
rows,cols,ch = image.shape
pts1 = np.float32([[56,65],[368,52],[28,387],[389,390]])
pts2 = np.float32([[0,0],[300,0],[0,300],[300,300]])
M = cv.getPerspectiveTransform(pts1,pts2)
dst = cv.warpPerspective(image,M,(300,300))

# %%
cv.imshow('dst',dst)
cv.waitKey(0)
# Out:
# -1

# %%
kernel = np.ones((3,3),np.float32)/25

# %%
dst = cv.filter2D(image,-1,kernel)
cv.imshow('dst',dst)
cv.waitKey(0)
# Out:
# -1

# %%
blur = cv.blur(image,(5,5))
cv.imshow('blur',blur)
cv.waitKey(0)
# Out:
# -1

# %%
blur = cv.GaussianBlur(image,(5,5),0)
cv.imshow('blur',blur)
cv.waitKey(0)
# Out:
# -1

# %%
median = cv.medianBlur(image,5)
cv.imshow('median',median)
cv.waitKey(0)
# Out:
# -1

# %%
blur = cv.bilateralFilter(image,5,75,75)
cv.imshow('blur',blur)
cv.waitKey(0)
# Out:
# -1

# %%
cv.imshow('inage',image)
cv.waitKey(0)
# Out:
# -1

# %%
erode =cv.erode(thresh,(3,3),iterations = 3)
cv.imshow('eroded',erode)
cv.waitKey(0)
# Out:
# -1

# %%
dilate = cv.dilate(erode,(3,3),iterations = 3)
cv.imshow('dilatde',dilated)
cv.waitKey(0)
# Out:
# -1

# %%
opene = cv.morphologyEx(thresh,cv.MORPH_OPEN,(3,3))
cv.imshow('opene',opene)
cv.waitKey(0)
# Out:
# -1

# %%
close = cv.morphologyEx(thresh,cv.MORPH_CLOSE,(3,3))
cv.imshow('close',close)
cv.waitKey(0)
# Out:
# -1

# %%
tophat = cv.morphologyEx(thresh,cv.MORPH_TOPHAT,(3,3))
cv.imshow('tophat',tophat)
cv.waitKey(0)
# Out:
# -1

# %%
blackhat = cv.morphologyEx(thresh,cv.MORPH_TOPHAT,(3,3))
cv.imshow('blackkhat',blackhat)
cv.waitKey(0)
# Out:
# -1

# %%
gradient = cv.morphologyEx(thresh,cv.MORPH_GRADIENT,(3,3))
cv.imshow('gradient',gradient)
cv.waitKey(0)
# Out:
# -1

# %%
sobelx = cv.Sobel(thresh,cv.CV_64F,1,0,ksize = 3)
cv.imshow('sobelx',sobelx)
cv.waitKey(0)
# Out:
# -1

# %%
sobely = cv.Sobel(thresh,cv.CV_64F,0,1,ksize = 3)
cv.imshow('sobely',sobely)
cv.waitKey(0)
# Out:
# -1

# %%
laplacian = cv.Laplacian(thresh,cv.CV_64F)
cv.imshow('laplacian',laplacian)
cv.waitKey(0)
# Out:
# -1

# %%
sobelx8 =cv.Sobel(thresh,cv.CV_8U,1,0,ksize = 3)
cv.imshow('sobelx8',sobelx8)
cv.waitKey(0)
# Out:
# -1

# %%
blank = np.zeros((500,500),dtype = np.uint8)

blank[150:350,150:350] = 255
cv.imshow('blank',blank)
cv.waitKey(0)
# Out:
# -1

# %%
sobelx = cv.Sobel(blank,cv.CV_64F,2,0,ksize = 3)
sobelx2 = np.absolute(sobelx)
sobel8 = np.uint8(sobelx2)
cv.imshow('sobel8',sobelx2)
cv.waitKey(0)
# Out:
# -1

# %%
sobel8u = cv.Sobel(blank,cv.CV_8U,1,0,ksize = 3)
cv.imshow('sobel',sobel8u)
cv.waitKey(0)
# Out:
# -1

# %%
cany = cv.Canny(image,100,200)
cv.imshow('cany',cany)
cv.waitKey(0)
# Out:
# -1

# %%
lower = cv.pyrDown(image)
cv.imshow('lower',lower)
cv.waitKey(0)
# Out:
# -1

# %%
upper = cv.pyrUp(image)
cv.imshow('upper',upper)
cv.waitKey(0)
# Out:
# -1

# %%
lowerer = cv.pyrDown(lower)
cv.imshow('lowerer',lowerer)
cv.waitKey(0)
# Out:
# -1

# %%
image2  = cv.imread("C:/Users/VEDIT/Desktop/mike/387011_3d-cute-wallpapers-for-desktop-hd-1-jpg_1024x768_h.jpg")
gray = cv.cvtColor(image2,cv.COLOR_BGR2GRAY)
ret,thresh = cv.threshold(image2,125,255,cv.THRESH_BINARY)

# %%
blank = np.zeros(image.shape[:2],np.float32)
cv.imshow('blank',blank)
cv.waitKey(0)
# Out:
# -1

# %%
# contours,hierachy = cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
image , contours, hierarchy = cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
# cv.drawContours(image2,contours,-1,(0,255,0),3)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-35299962bc75> in <module>
#       1 # contours,hierachy = cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
# ----> 2 image , contours, hierarchy = cv.findContours(thresh,cv.RETR_TREE,cv.CHAIN_APPROX_SIMPLE)
#       3 # cv.drawContours(image2,contours,-1,(0,255,0),3)
#
# error: OpenCV(4.0.1) C:\ci\opencv-suite_1573470242804\work\modules\imgproc\src\contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
cv.imshow('blank',image)
cv.waitKey(0)
# Out:
# -1
